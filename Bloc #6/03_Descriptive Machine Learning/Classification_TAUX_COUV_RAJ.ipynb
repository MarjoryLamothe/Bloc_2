# %%
import pandas as pd
import numpy as np
import plotly.express as px

from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelEncoder
from sklearn.impute import KNNImputer
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.model_selection import cross_val_score, GridSearchCV

from sklearn.linear_model import Lasso, LogisticRegression

# %%
data_merge = pd.read_excel('/content/drive/MyDrive/big_merge_V2_meteo_SAT.xlsx', sheet_name='Sheet1')

# %%
data_merge.drop('Unnamed: 0', axis=1, inplace=True)

# %% [markdown]
# Target definition :

# %%
TARGET =  'TAUX_COUV_RAJ'

# %%
fig = px.histogram(data_merge[TARGET], nbins=100)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="46f23e69-a24d-41eb-ba06-259457add590" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("46f23e69-a24d-41eb-ba06-259457add590")) {                    Plotly.newPlot(                        "46f23e69-a24d-41eb-ba06-259457add590",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"variable=TAUX_COUV_RAJ<br>value=%{x}<br>count=%{y}<extra></extra>","legendgroup":"TAUX_COUV_RAJ","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"TAUX_COUV_RAJ","nbinsx":100,"offsetgroup":"TAUX_COUV_RAJ","orientation":"v","showlegend":true,"x":[-1,2,2,2,6,-1,4,6,6,-1,5,5,5,6,-1,5,5,4,5,-1,6,-1,6,5,3,3,3,-1,-1,3,2,4,4,2,-1,5,-1,3,3,3,5,-1,4,6,2,2,-1,3,4,-1,4,5,3,-1,2,2,5,-1,3,5,3,5,-1,4,6,-1,5,3,6,-1,4,4,3,-1,3,2,-1,2,6,3,3,4,5,-1,-1,6,4,6,2,6,-1,5,4,3,-1,6,3,-1,2,2,6,-1,4,5,6,-1,5,4,-1,4,2,4,5,-1,3,3,4,4,-1,5,3,2,3,-1,-1,5,5,6,3,-1,4,5,-1,6,5,5,-1,5,5,5,3,2,-1,3,-1,4,3,3,3,4,4,-1,2,4,4,-1,4,3,3,-1,4,3,4,-1,-1,6,5,5,5,4,3,-1,2,2,3,-1,3,4,-1,6,5,3,-1,4,6,4,-1,3,-1,3,1,2,2,-1,3,3,4,-1,3,2,4,4,-1,3,3,3,-1,2,5,4,6,-1,4,-1,6,2,-1,3,3,2,2,3,-1,2,3,3,-1,4,-1,5,4,2,5,6,-1,4,5,6,-1,6,2,5,3,-1,-1,2,3,3,6,-1,4,3,-1,3,6,4,4,-1,3,5,3,-1,5,3,5,-1,5,5,-1,3,3,3,2,-1,2,3,5,-1,6,5,6,4,-1,3,3,2,-1,2,4,-1,6,4,4,4,6,-1,4,-1,5,2,6,6,6,-1,4,3,-1,3,2,-1,2,2,-1,2,2,2,-1,5,5,3,5,3,-1,5,4,3,-1,4,5,4,2,-1,2,2,3,-1,3,1,3,-1,-1,3,5,3,-1,6,3,2,4,-1,3,4,5,5,-1,5,-1,4,5,6,-1,2,1,4,2,3,3,-1,6,5,4,-1,5,4,5,-1,5,4,4,-1,4,3,5,-1,-1,4,3,3,4,5,-1,3,-1,5,5,4,-1,4,5,5,-1,3,4,5,-1,3,5,4,4,-1,2,3,3,5,-1,4,3,-1,2,2,-1,3,2,3,3,2,-1,3,3,-1,3,5,2,-1,3,2,-1,6,6,3,-1,2,2,2,5,4,4,-1,4,3,-1,4,2,-1,6,6,4,-1,3,5,5,-1,4,4,4,6,3,-1,5,4,4,-1,5,3,3,-1,-1,3,2,3,4,6,6,-1,3,4,-1,5,3,6,6,-1,2,-1,2,3,3,3,2,-1,3,2,3,-1,2,-1,2,2,6,5,-1,4,3,4,-1,3,-1,1,2,1,3,3,3,-1,-1,2,2,2,-1,4,5,2,3,4,-1,3,3,-1,6,4,3,-1,4,3,-1,4,2,3,3,-1,2,3,-1,4,4,6,3,-1,3,3,3,4,-1,5,5,5,-1,2,3,3,-1,2,-1,4,4,6,-1,5,6,5,-1,6,5,5,2,2,4,-1,4,2,-1,4,-1,5,2,3,-1,2,3,3,2,-1,2,2,5,4,4,-1,4,3,2,-1,2,-1,3,3,6,-1,4,6,-1,3,2,2,2,3,-1,2,4,2,-1,6,-1,3,2,2,4,-1,4,4,4,-1,3,6,1,1,1,-1,3,-1,4,3,2,4,-1,3,2,2,3,-1,-1,6,6,6,5,4,6,-1,4,3,4,-1,4,5,-1,5,-1,2,2,1,5,6,3,-1,4,3,3,-1,5,3,-1,6,-1,4,3,3,2,4,4,-1,2,2,2,-1,4,5,5,-1,4,4,5,-1,2,-1,2,2,3,-1,2,3,-1,4,5,3,6,6,-1,6,3,4,-1,3,4,5,-1,4,-1,5,3,3,2,2,2,-1,3,2,2,-1,-1,1,2,1,5,-1,4,3,4,-1,4,2,-1,3,4,3,-1,2,1,2,-1,2,3,2,2,3,1,-1,-1,2,1,1,1,2,-1,1,6,4,-1,1,-1,4,5,4,-1,2,2,3,-1,5,4,3,4,-1,4,4,2,3,-1,2,-1,2,2,2,-1,4,3,3,2,2,-1,3,3,4,3,-1,3,-1,2,3,3,3,3,-1,-1,4,2,5,3,3,3,-1,1,-1,1,2,3,-1,2,2,-1,4,2,2,3,-1,5,5,2,6,-1,4,5,6,-1,5,-1,2,2,2,-1,1,1,1,5,3,-1,3,3,-1,2,2,4,5,5,-1,4,4,4,-1,-1,5,2,4,4,4,-1,6,4,4,3,-1,3,-1,5,4,4,-1,4,5,4,-1,3,2,5,-1,3,3,-1,2,1,2,3,-1,2,6,3,3,5,-1,6,-1,6,6,4,-1,4,4,4,5,-1,3,2,-1,2,3,4,1,-1,5,-1,2,4,2,4,6,-1,5,2,3,4,-1,6,6,5,-1,-1,2,3,1,2,-1,5,2,4,-1,1,4,2,2,2,-1,5,3,5,-1,3,3,4,-1,2,-1,1,2,-1,1,3,3,3,-1,3,3,2,2,-1,1,3,6,-1,6,3,-1,2,3,3,4,-1,4,2,1,-1,2,4,4,4,-1,5,6,4,-1,4,6,-1,3,2,3,-1,2,-1,3,2,2,-1,2,2,1,3,-1,4,3,-1,5,6,5,3,4,-1,4,-1,2,2,2,2,2,2,-1,-1,4,2,3,4,-1,2,4,1,3,-1,3,2,5,6,-1,-1,4,4,3,-1,5,2,3,-1,6,4,5,2,2,-1,4,3,4,1,-1,5,5,-1,4,4,3,3,-1,-1,3,5,6,-1,3,4,4,-1,6,5,3,6,-1,6,4,2,2,-1,3,-1,3,3,2,6,-1,6,5,5,5,-1,6,4,3,3,-1,4,3,-1,4,4,2,-1,3,4,2,-1,2,-1,2,3,3,2,3,-1,4,-1,1,2,3,-1,5,6,5,1,-1,2,2,5,2,2,-1,1,1,-1,2,2,3,1,-1,-1,3,3,2,-1,3,3,3,6,5,-1,4,4,-1,4,4,3,3,-1,3,3,-1,5,3,-1,5,5,4,4,4,5,-1,3,-1,4,4,5,-1,4,4,3,5,3,-1,4,-1,4,5,6,5,3,-1,3,4,4,-1,-1,4,5,4,3,4,3,-1,2,1,1,-1,3,4,-1,6,1,2,-1,2,-1,3,3,2,4,-1,2,2,2,2,3,-1,5,-1,5,5,-1,2,2,3,-1,6,4,3,2,2,2,-1,2,-1,3,2,3,-1,5,5,6,-1,6,6,-1,1,2,2,2,-1,3,5,2,-1,3,2,1,1,2,-1,6,4,-1,6,4,4,3,-1,2,2,-1,3,-1,4,4,4,4,2,5,-1,6,3,-1,6,6,-1,6,6,3,-1,3,3,2,4,-1,3,3,2,-1,2,4,4,3,-1,-1,4,4,6,3,-1,3,3,4,4,-1,4,5,3,3,-1,4,-1,4,4,3,3,-1,3,-1,4,4,4,-1,3,3,3 ...

# %%
data_red = data_merge.loc[data_merge[TARGET]!=np.nan,:]
data_red = data_red.loc[data_merge[TARGET]!=-1,:]

# %%
len(data_red)
# Out:
# 7174

# %%
Y = data_red[TARGET]

# %%
Y
# Out:
# 1       2
# 2       2
# 3       2
# 4       6
# 6       4
#        ..
# 9605    2
# 9606    4
# 9608    2
# 9610    2
# 9611    2
# Name: TAUX_COUV_RAJ, Length: 7174, dtype: int64

# %% [markdown]
# Particular preprocessing for features :

# %%
data_red['LFI'] = data_red['LFI'].map({'LFI1':1,
                                       'LFI2':2,
                                       'LFI3':3,
                                       'LFI4':4})

# %% [markdown]
# preprocess LFI

# %% [markdown]
# Selection of features :

# %%
targets_cat__ord_feat = ['DEGRAD_PPL'] #'TAUX_COUV_RAJ'

# %%
targets_numeric_feat = ['PERF_CROI','SURF_TER_HA', '25_GRID_PER', 'UNIT_VOL_BOIS_MANQUANT', 'UNIT_ACCR']

# %%
cat_strict = ['PRODREG','UNIT_VEG_GROS','MODE_REGEN','INTENSITE_EXPLOIT','TRACES_FEU','NIV_DEV','RELIEF','DEG_FERMETURE','STR_PPL', 'TYPE_FORET305', 'ESPECE_DOM', 'TYPE_FORET'] #'TYP_RAJ_PPL','TAUX_COUV_RAJ_ASS'

# %%
cat_ord_miss = ['TAILLE_PPL', 'MELANGE', 'HT_VEG'] # enlever : 'LFI'

# %%
numerical = ['ALT','SLOPE25','QUAL_STATION','AGE_PPL','DIV_STR_PPL','DDOM','TIGES_VIV_H', 'SDI', 'EPIC_PER',	'SAPIN_PER', 'PIN_PER', 'MELEZ_PER'	,'ARO_PER', 'OTHER_CONIF_PER'	,'HETR_PER' ,'ERAB_PER', 'FREN_PER', 'CHEN_PER', 'DGANTCA', 'OTHER_FEUILL_PER',	'CONIF_PER_STD', 'ARBUST_PER', 'FEUILL_PER', 'CONIF_PER', 'PROCESS_SILVA', 'V_ALL',	'V_FICHT', 'V_TANNE',	'V_FOEHR', 'V_LARCH',	'V_ARVEN', 'V_UENDH',	'V_BUCHE', 'V_AHORN',	'V_ESCHE',	'V_EICHE', 'V_CASTA',	'V_UELBH', 'DBH', 'HAUTEUR_ARBRE', 'AGE_ARBRE', 'PRCP', 'TAVE_AVG',	'TAVE', 'TAVE_GROWTH', 'PRCP_S_S',	'PRCP_G_S', 'NDVI', 'EVI', 'NDMI', 'NDWI', 'DSWI'] # enlever :

# %% [markdown]
# Preprocessing for cat_ord_miss :

# %%
for cat in cat_ord_miss:
  data_red[cat] = data_red[cat].apply(lambda v : v if v!=-1 else np.nan)

# %%
for cat in cat_ord_miss:
  print(data_red[cat].dtypes)
# Out:
# float64
# float64
# int64

# %%
numerics_feats = numerical + targets_numeric_feat + cat_ord_miss
categorical_feats = cat_strict + targets_cat__ord_feat

# %%
len(numerics_feats)
# Out:
# 60

# %%
len(categorical_feats)
# Out:
# 13

# %%
data_red = data_red[[cat for cat in numerics_feats + categorical_feats]]

# %%
numerics_transforms = Pipeline(
    [('imputer',KNNImputer()),
    ('encoder',StandardScaler())
])
categorials_transforms = Pipeline([
    ('imputer',KNNImputer()),
    ('encoder',OneHotEncoder(drop="first"))
])

preprocessor = ColumnTransformer(
    [("num", numerics_transforms, numerics_feats),
     ("cat", categorials_transforms, categorical_feats)])

# %%
X_train, X_test, y_train, y_test = train_test_split(data_red, Y, test_size=0.2, random_state=2, stratify=Y)

# %%
X_train = preprocessor.fit_transform(X_train)
X_test = preprocessor.transform(X_test)

# %%
np.shape(X_train)
# Out:
# (5739, 147)

# %%
y_train
# Out:
# 4854    2
# 8044    2
# 6661    2
# 3066    1
# 1183    2
#        ..
# 6704    3
# 8640    3
# 7449    3
# 7168    2
# 4207    3
# Name: TAUX_COUV_RAJ, Length: 5739, dtype: int64

# %%
model =  LogisticRegression(max_iter=10000)

# %%
params = {
    'C':[0.08, 0.1, 0.12]
}

# %%
grid = GridSearchCV(model, param_grid=params, scoring='accuracy', verbose=1)

# %%
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# GridSearchCV(estimator=LogisticRegression(max_iter=10000),
#              param_grid={'C': [0.08, 0.1, 0.12]}, scoring='accuracy',
#              verbose=1)

# %%
grid.best_estimator_
# Out:
# LogisticRegression(C=0.1, max_iter=10000)

# %%
y_pred = grid.best_estimator_.predict(X_train)
y_pred_test = grid.best_estimator_.predict(X_test)

# %%
r2_score(y_train, y_pred)
# Out:
# 0.3646601116018672

# %%
r2_score(y_test, y_pred_test)
# Out:
# 0.330869982639466

# %%
train_scores = cross_val_score(grid.best_estimator_, X_train, y_train, cv=5)
test_scores = cross_val_score(grid.best_estimator_, X_test, y_test, cv=5)
print(f'Train score mean : {np.mean(train_scores)}')
print(f'Train score std : {np.std(train_scores)}')
print(f'Test score mean : {np.mean(test_scores)}')
print(f'Test score std : {np.std(test_scores)}')
# Out:
# Train score mean : 0.4361372949885932
# Train score std : 0.00799429109109187
# Test score mean : 0.41602787456445994
# Test score std : 0.02002802489644588

# %%
len(grid.best_estimator_.coef_)
# Out:
# 6

# %%
preprocessor.feature_names_in_
# Out:
# array(['ALT', 'SLOPE25', 'QUAL_STATION', 'AGE_PPL', 'DIV_STR_PPL', 'DDOM',
#        'TIGES_VIV_H', 'SDI', 'EPIC_PER', 'SAPIN_PER', 'PIN_PER',
#        'MELEZ_PER', 'ARO_PER', 'OTHER_CONIF_PER', 'HETR_PER', 'ERAB_PER',
#        'FREN_PER', 'CHEN_PER', 'DGANTCA', 'OTHER_FEUILL_PER',
#        'CONIF_PER_STD', 'ARBUST_PER', 'FEUILL_PER', 'CONIF_PER',
#        'PROCESS_SILVA', 'V_ALL', 'V_FICHT', 'V_TANNE', 'V_FOEHR',
#        'V_LARCH', 'V_ARVEN', 'V_UENDH', 'V_BUCHE', 'V_AHORN', 'V_ESCHE',
#        'V_EICHE', 'V_CASTA', 'V_UELBH', 'DBH', 'HAUTEUR_ARBRE',
#        'AGE_ARBRE', 'PRCP', 'TAVE_AVG', 'TAVE', 'TAVE_GROWTH', 'PRCP_S_S',
#        'PRCP_G_S', 'NDVI', 'EVI', 'NDMI', 'NDWI', 'DSWI', 'PERF_CROI',
#        'SURF_TER_HA', '25_GRID_PER', 'UNIT_VOL_BOIS_MANQUANT',
#        'UNIT_ACCR', 'TAILLE_PPL', 'MELANGE', 'HT_VEG', 'PRODREG',
#        'UNIT_VEG_GROS', 'MODE_REGEN', 'INTENSITE_EXPLOIT', 'TRACES_FEU',
#        'NIV_DEV', 'RELIEF', 'DEG_FERMETURE', 'STR_PPL', 'TYPE_FORET305',
#        'ESPECE_DOM', 'TYPE_FORET', 'DEGRAD_PPL'], dtype=object)

# %%
list_features_in = []
for feat in numerics_feats:
  list_features_in.append(feat)
for cat in categorical_feats:
  nb_lab = len(data_red[cat].unique())-1
  for i in range(nb_lab):
    list_features_in.append(f'{cat}_{i}')

# %%
df_coef_inter = pd.DataFrame(grid.best_estimator_.coef_)

# %%
df_coef = pd.DataFrame(abs(df_coef_inter).sum(), columns=['Coeff'])

# %%
df_coef['Features'] = list_features_in

# %%
df_coef = df_coef.set_index('Features')

# %%
fig = px.bar(df_coef['Coeff'], title=f"Features importance for target : {TARGET} with Lasso Linear Regression")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="36e31ca3-13ad-4400-a42d-9a7460c0af51" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("36e31ca3-13ad-4400-a42d-9a7460c0af51")) {                    Plotly.newPlot(                        "36e31ca3-13ad-4400-a42d-9a7460c0af51",                        [{"alignmentgroup":"True","hovertemplate":"variable=Coeff<br>Features=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Coeff","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Coeff","offsetgroup":"Coeff","orientation":"v","showlegend":true,"textposition":"auto","x":["ALT","SLOPE25","QUAL_STATION","AGE_PPL","DIV_STR_PPL","DDOM","TIGES_VIV_H","SDI","EPIC_PER","SAPIN_PER","PIN_PER","MELEZ_PER","ARO_PER","OTHER_CONIF_PER","HETR_PER","ERAB_PER","FREN_PER","CHEN_PER","DGANTCA","OTHER_FEUILL_PER","CONIF_PER_STD","ARBUST_PER","FEUILL_PER","CONIF_PER","PROCESS_SILVA","V_ALL","V_FICHT","V_TANNE","V_FOEHR","V_LARCH","V_ARVEN","V_UENDH","V_BUCHE","V_AHORN","V_ESCHE","V_EICHE","V_CASTA","V_UELBH","DBH","HAUTEUR_ARBRE","AGE_ARBRE","PRCP","TAVE_AVG","TAVE","TAVE_GROWTH","PRCP_S_S","PRCP_G_S","NDVI","EVI","NDMI","NDWI","DSWI","PERF_CROI","SURF_TER_HA","25_GRID_PER","UNIT_VOL_BOIS_MANQUANT","UNIT_ACCR","TAILLE_PPL","MELANGE","HT_VEG","PRODREG_0","PRODREG_1","PRODREG_2","PRODREG_3","UNIT_VEG_GROS_0","UNIT_VEG_GROS_1","UNIT_VEG_GROS_2","UNIT_VEG_GROS_3","UNIT_VEG_GROS_4","UNIT_VEG_GROS_5","UNIT_VEG_GROS_6","UNIT_VEG_GROS_7","UNIT_VEG_GROS_8","UNIT_VEG_GROS_9","UNIT_VEG_GROS_10","UNIT_VEG_GROS_11","UNIT_VEG_GROS_12","UNIT_VEG_GROS_13","UNIT_VEG_GROS_14","UNIT_VEG_GROS_15","UNIT_VEG_GROS_16","MODE_REGEN_0","MODE_REGEN_1","MODE_REGEN_2","MODE_REGEN_3","INTENSITE_EXPLOIT_0","INTENSITE_EXPLOIT_1","INTENSITE_EXPLOIT_2","TRACES_FEU_0","NIV_DEV_0","NIV_DEV_1","NIV_DEV_2","NIV_DEV_3","NIV_DEV_4","NIV_DEV_5","RELIEF_0","RELIEF_1","RELIEF_2","RELIEF_3","DEG_FERMETURE_0","DEG_FERMETURE_1","DEG_FERMETURE_2","DEG_FERMETURE_3","DEG_FERMETURE_4","DEG_FERMETURE_5","DEG_FERMETURE_6","DEG_FERMETURE_7","STR_PPL_0","STR_PPL_1","STR_PPL_2","STR_PPL_3","TYPE_FORET305_0","TYPE_FORET305_1","TYPE_FORET305_2","TYPE_FORET305_3","TYPE_FORET305_4","TYPE_FORET305_5","TYPE_FORET305_6","TYPE_FORET305_7","TYPE_FORET305_8","TYPE_FORET305_9","TYPE_FORET305_10","TYPE_FORET305_11","TYPE_FORET305_12","ESPECE_DOM_0","ESPECE_DOM_1","ESPECE_DOM_2","ESPECE_DOM_3","ESPECE_DOM_4","ESPECE_DOM_5","ESPECE_DOM_6","ESPECE_DOM_7","ESPECE_DOM_8","ESPECE_DOM_9","ESPECE_DOM_10","ESPECE_DOM_11","TYPE_FORET_0","TYPE_FORET_1","TYPE_FORET_2","TYPE_FORET_3","TYPE_FORET_4","DEGRAD_PPL_0","DEGRAD_PPL_1","DEGRAD_PPL_2","DEGRAD_PPL_3","DEGRAD_PPL_4","DEGRAD_PPL_5"],"xaxis":"x","y":[1.0466829886392812,0.8118390241681386,0.39136438487993985,1.5994226148787658,1.6009326669520656,0.5718096509759074,0.7674959404917737,2.5058607493966525,0.3161676787876182,0.5842168601972119,0.4069538571217272,0.23942770587194093,0.8808342511251018,0.2677776719892623,0.6893380644295106,0.2854006534491083,0.2719873311993812,0.6810694105532933,0.6030244950676282,0.4504496364082634,0.32236520934243934,0.200743702153406,0.6822032505655204,0.43631635130980284,0.21920826277597746,1.0694988491828816,0.46579816435277666,0.5381985383937974,0.4848769989538807,0.6833132969120412,0.47153133853082313,0.31314325256434455,0.5919025628855374,0.2973715506877974,0.6136975803802278,0.3655707265712078,0.7019985704344116,0.23384433590723988,0.4699988491655456,0.4230735184906661,0.5009973672814851,0.08268613703247536,0.651146516641134,0.24231230896098066,0.4456385888580072,0.27402282780197834,0.34173902541847667,0.9165866453012241,0.4090460888104501,0.19626470035817567,1.1110165725451697,0.8562423814911673,0.6300283790119362,1.0433623531414213,0.32663418082207946,0.8694358994135766,0.22820563137682592,0. ...
