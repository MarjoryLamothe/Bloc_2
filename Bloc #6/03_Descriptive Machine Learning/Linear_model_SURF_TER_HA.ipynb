# %%
import pandas as pd
import numpy as np
import plotly.express as px

from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelEncoder
from sklearn.impute import KNNImputer
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.model_selection import cross_val_score, GridSearchCV

from sklearn.linear_model import Lasso, LogisticRegression

# %%
data_merge = pd.read_excel('/content/drive/MyDrive/big_merge_V2_meteo_SAT.xlsx', sheet_name='Sheet1')

# %%
data_merge.drop('Unnamed: 0', axis=1, inplace=True)

# %% [markdown]
# Target definition :

# %%
TARGET =  'SURF_TER_HA'

# %%
fig = px.histogram(data_merge[TARGET], nbins=100)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="ab7c7925-8f1b-418d-a73f-cfe34765eee9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ab7c7925-8f1b-418d-a73f-cfe34765eee9")) {                    Plotly.newPlot(                        "ab7c7925-8f1b-418d-a73f-cfe34765eee9",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"variable=SURF_TER_HA<br>value=%{x}<br>count=%{y}<extra></extra>","legendgroup":"SURF_TER_HA","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"SURF_TER_HA","nbinsx":100,"offsetgroup":"SURF_TER_HA","orientation":"v","showlegend":true,"x":[27.79,35.11,45.71,43.99,53.44,53.38,27.61,31.31,31.5,26.7,40.55,37.33,16.99,3.34,0.0,11.0,26.3,0.0,22.69,23.32,27.97,26.67,29.92,33.24,14.64,19.18,20.51,19.12,22.32,24.53,14.27,23.28,2.51,40.16,64.42,0.0,30.21,43.18,38.75,47.09,38.44,35.39,31.8,40.16,31.48,26.34,28.29,24.65,32.09,27.61,31.29,33.5,25.22,14.1,19.64,11.44,42.74,33.04,32.61,42.19,47.31,27.36,15.17,36.94,3.89,0.0,15.62,20.81,15.85,44.22,23.17,24.23,56.29,16.59,64.41,61.56,0.0,29.33,11.83,24.0,57.19,55.51,45.69,54.94,0.0,2.27,28.24,16.31,44.09,20.04,36.52,24.6,11.95,31.88,31.24,13.93,32.77,14.57,50.46,48.57,28.09,27.07,24.05,29.26,12.57,8.93,23.84,19.53,76.14,26.68,77.31,22.12,76.08,62.19,74.03,73.0,51.48,55.65,53.28,42.98,53.16,43.1,23.56,39.17,30.65,36.8,32.63,34.86,21.01,27.78,30.57,8.62,29.25,37.87,49.32,48.88,22.88,5.8,19.31,13.28,48.15,38.62,43.0,40.36,38.62,78.66,75.91,58.23,34.74,78.5,35.93,108.58,0.0,34.38,1.66,27.64,38.3,35.3,51.99,54.46,24.28,22.06,19.92,13.08,10.25,0.0,17.71,13.06,32.26,34.67,30.58,23.83,29.75,15.54,14.54,23.37,34.68,21.87,43.3,11.78,45.47,35.53,41.44,36.65,0.58,9.78,0.0,18.42,34.91,37.25,39.4,44.0,41.22,27.81,31.23,45.85,6.01,56.79,47.87,52.67,6.28,26.61,40.48,16.51,46.42,48.22,43.64,46.12,35.42,41.3,34.47,36.57,30.12,41.47,33.05,39.93,25.59,42.86,35.43,53.59,48.71,51.61,40.53,48.72,18.19,20.56,29.03,22.89,21.3,26.49,23.96,27.6,11.98,36.57,28.7,16.77,35.47,28.67,36.02,23.41,58.94,56.04,46.93,34.62,56.52,90.71,73.86,62.48,9.92,29.6,23.58,12.68,0.0,0.57,0.0,0.0,36.95,29.28,30.22,26.77,29.43,5.21,38.49,21.24,14.86,32.34,34.23,26.09,29.78,31.54,30.4,30.49,29.69,19.37,29.95,31.1,31.19,37.18,24.71,22.01,11.8,26.51,8.84,50.4,28.3,35.86,18.57,35.16,28.09,45.27,32.04,49.99,25.16,22.12,25.71,24.5,19.88,53.96,40.36,39.98,32.43,39.23,31.81,37.04,45.6,42.03,41.74,35.79,61.74,48.11,66.94,52.76,35.75,49.58,38.98,49.22,19.62,14.92,19.49,10.8,36.62,38.82,31.12,46.42,63.84,74.89,48.12,74.21,35.12,34.98,25.59,29.96,33.09,27.06,30.48,23.72,38.52,31.93,37.69,28.25,28.44,44.78,37.02,40.85,50.65,39.42,47.31,45.1,38.62,18.0,32.86,31.42,23.81,27.09,17.28,34.16,33.77,41.98,30.98,37.02,9.63,57.36,73.32,41.2,25.76,21.35,28.17,24.95,35.07,41.36,47.21,25.29,33.96,27.69,26.51,33.73,52.29,35.34,53.63,45.2,13.54,15.55,19.38,25.28,24.53,28.09,28.61,28.84,8.84,12.91,17.68,21.1,23.07,24.91,17.94,22.88,40.68,21.33,4.68,23.59,52.54,20.92,27.13,59.47,41.15,39.63,31.06,39.85,46.76,30.64,55.31,54.05,43.12,27.02,18.27,34.73,36.91,37.03,23.73,49.27,41.15,41.69,40.92,41.76,20.62,23.25,21.84,18.57,33.36,32.74,40.55,33.36,29.48,42.07,75.83,64.14,30.97,11.17,25.79,28.33,81.57,139.47,98.2,123.08,59.1,45.48,54.45,46.45,39.63,40.73,56.17,51.03,73.53,62.64,36.51,47.93,43.01,36.47,39.08,39.07,19.08,20.27,16.33,26.86,8.38,21.29,31.05,16.55,44.01,42.56,45.79,37.52,22.89,28.44,27.7,21.18,36.72,44.36,50.79,59.58,18.34,23.91,12.86,18.33,13.57,58.96,49.24,70.7,19.33,23.66,22.55,61.56,29.15,3.49,35.3,24.01,33.29,37.2,44.9,21.52,59.68,65.01,56.95,53.64,62.86,49.41,59.51,44.35,19.3,17.16,9.43,16.71,37.95,40.63,41.42,38.31,45.95,52.11,55.04,56.64,35.18,37.41,30.38,23.04,47.57,50.18,58.0,53.93,65.1,58.86,60.38,44.38,44.69,47.23,46.04,53.23,52.91,20.05,15.84,32.62 ...

# %%
data_red = data_merge.loc[data_merge[TARGET]!=np.nan,:]
data_red = data_red.loc[data_merge[TARGET]!=-1,:]

# %%
len(data_red)
# Out:
# 9612

# %%
Y = data_red[TARGET]

# %%
Y
# Out:
# 0       27.79
# 1       35.11
# 2       45.71
# 3       43.99
# 4       53.44
#         ...
# 9607    24.94
# 9608    17.05
# 9609    11.48
# 9610    26.58
# 9611    26.87
# Name: SURF_TER_HA, Length: 9612, dtype: float64

# %% [markdown]
# Particular preprocessing for features :

# %%
data_red['LFI'] = data_red['LFI'].map({'LFI1':1,
                                       'LFI2':2,
                                       'LFI3':3,
                                       'LFI4':4})

# %% [markdown]
# preprocess LFI

# %% [markdown]
# Selection of features :

# %%
targets_cat__ord_feat = ['DEGRAD_PPL', 'TAUX_COUV_RAJ' ] # enlever :

# %%
targets_numeric_feat = ['PERF_CROI', '25_GRID_PER', 'UNIT_VOL_BOIS_MANQUANT', 'UNIT_ACCR'] #'SURF_TER_HA'

# %%
cat_strict = ['PRODREG','UNIT_VEG_GROS','MODE_REGEN','INTENSITE_EXPLOIT','TRACES_FEU','NIV_DEV','RELIEF','DEG_FERMETURE','STR_PPL', 'TYPE_FORET305', 'TYP_RAJ_PPL','TAUX_COUV_RAJ_ASS', 'ESPECE_DOM', 'TYPE_FORET'] #

# %%
cat_ord_miss = ['TAILLE_PPL', 'MELANGE', 'HT_VEG', 'LFI'] # enlever :

# %%
numerical = ['ALT','SLOPE25','QUAL_STATION','AGE_PPL','DIV_STR_PPL','DDOM','TIGES_VIV_H', 'EPIC_PER',	'SAPIN_PER', 'PIN_PER', 'MELEZ_PER'	,'ARO_PER', 'OTHER_CONIF_PER'	,'HETR_PER' ,'ERAB_PER', 'FREN_PER', 'CHEN_PER', 'DGANTCA', 'OTHER_FEUILL_PER',	'CONIF_PER_STD', 'ARBUST_PER', 'FEUILL_PER', 'CONIF_PER', 'PROCESS_SILVA', 'V_ALL',	'V_FICHT', 'V_TANNE',	'V_FOEHR', 'V_LARCH',	'V_ARVEN', 'V_UENDH',	'V_BUCHE', 'V_AHORN',	'V_ESCHE',	'V_EICHE', 'V_CASTA',	'V_UELBH', 'DBH', 'HAUTEUR_ARBRE', 'AGE_ARBRE', 'PRCP', 'TAVE_AVG',	'TAVE', 'TAVE_GROWTH', 'PRCP_S_S',	'PRCP_G_S', 'NDVI', 'EVI', 'NDMI', 'NDWI', 'DSWI'] # enlever : 'SDI'

# %% [markdown]
# Preprocessing for cat_ord_miss :

# %%
for cat in cat_ord_miss:
  data_red[cat] = data_red[cat].apply(lambda v : v if v!=-1 else np.nan)

# %%
for cat in cat_ord_miss:
  print(data_red[cat].dtypes)
# Out:
# float64
# float64
# int64
# int64

# %%
numerics_feats = numerical + targets_numeric_feat + cat_ord_miss
categorical_feats = cat_strict + targets_cat__ord_feat

# %%
len(numerics_feats)
# Out:
# 59

# %%
len(categorical_feats)
# Out:
# 16

# %%
data_red = data_red[[cat for cat in numerics_feats + categorical_feats]]

# %%
numerics_transforms = Pipeline(
    [('imputer',KNNImputer()),
    ('encoder',StandardScaler())
])
categorials_transforms = Pipeline([
    ('imputer',KNNImputer()),
    ('encoder',OneHotEncoder(drop="first"))
])

preprocessor = ColumnTransformer(
    [("num", numerics_transforms, numerics_feats),
     ("cat", categorials_transforms, categorical_feats)])

# %%
X_train, X_test, y_train, y_test = train_test_split(data_red, Y, test_size=0.2, random_state=2)

# %%
X_train = preprocessor.fit_transform(X_train)
X_test = preprocessor.transform(X_test)

# %%
np.shape(X_train)
# Out:
# (7689, 166)

# %%
model =  Lasso(max_iter=10000)

# %%
model.get_params().keys()
# Out:
# dict_keys(['alpha', 'copy_X', 'fit_intercept', 'max_iter', 'normalize', 'positive', 'precompute', 'random_state', 'selection', 'tol', 'warm_start'])

# %%
params = {
    'alpha':[0.001, 0.005, 0.01]
}

# %%
grid = GridSearchCV(model, param_grid=params, scoring='r2', verbose=1)

# %%
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# GridSearchCV(estimator=Lasso(max_iter=10000),
#              param_grid={'alpha': [0.001, 0.005, 0.01]}, scoring='r2',
#              verbose=1)

# %%
grid.best_estimator_
# Out:
# Lasso(alpha=0.001, max_iter=10000)

# %%
y_pred = grid.best_estimator_.predict(X_train)
y_pred_test = grid.best_estimator_.predict(X_test)

# %%
r2_score(y_train, y_pred)
# Out:
# 0.9672918837883745

# %%
r2_score(y_test, y_pred_test)
# Out:
# 0.9674569003815918

# %%
train_scores = cross_val_score(grid.best_estimator_, X_train, y_train, cv=5)
test_scores = cross_val_score(grid.best_estimator_, X_test, y_test, cv=5)
print(f'Train score mean : {np.mean(train_scores)}')
print(f'Train score std : {np.std(train_scores)}')
print(f'Test score mean : {np.mean(test_scores)}')
print(f'Test score std : {np.std(test_scores)}')
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.675e+01, tolerance: 5.493e+01
# Train score mean : 0.964953244104159
# Train score std : 0.012627911622180658
# Test score mean : 0.9597048828733581
# Test score std : 0.018146197911048507

# %%
len(grid.best_estimator_.coef_)
# Out:
# 166

# %%
list_features_in = []
for feat in numerics_feats:
  list_features_in.append(feat)
for cat in categorical_feats:
  nb_lab = len(data_red[cat].unique())-1
  for i in range(nb_lab):
    list_features_in.append(f'{cat}_{i}')

# %%
df_coef = pd.DataFrame(grid.best_estimator_.coef_, index=list_features_in, columns=['Coeff'])

# %%
fig = px.bar(df_coef['Coeff'], title=f"Features importance for target : {TARGET} with Lasso Linear Regression")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="9faf2aad-f67e-407a-96b5-3739f6f09d99" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9faf2aad-f67e-407a-96b5-3739f6f09d99")) {                    Plotly.newPlot(                        "9faf2aad-f67e-407a-96b5-3739f6f09d99",                        [{"alignmentgroup":"True","hovertemplate":"variable=Coeff<br>index=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Coeff","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Coeff","offsetgroup":"Coeff","orientation":"v","showlegend":true,"textposition":"auto","x":["ALT","SLOPE25","QUAL_STATION","AGE_PPL","DIV_STR_PPL","DDOM","TIGES_VIV_H","EPIC_PER","SAPIN_PER","PIN_PER","MELEZ_PER","ARO_PER","OTHER_CONIF_PER","HETR_PER","ERAB_PER","FREN_PER","CHEN_PER","DGANTCA","OTHER_FEUILL_PER","CONIF_PER_STD","ARBUST_PER","FEUILL_PER","CONIF_PER","PROCESS_SILVA","V_ALL","V_FICHT","V_TANNE","V_FOEHR","V_LARCH","V_ARVEN","V_UENDH","V_BUCHE","V_AHORN","V_ESCHE","V_EICHE","V_CASTA","V_UELBH","DBH","HAUTEUR_ARBRE","AGE_ARBRE","PRCP","TAVE_AVG","TAVE","TAVE_GROWTH","PRCP_S_S","PRCP_G_S","NDVI","EVI","NDMI","NDWI","DSWI","PERF_CROI","25_GRID_PER","UNIT_VOL_BOIS_MANQUANT","UNIT_ACCR","TAILLE_PPL","MELANGE","HT_VEG","LFI","PRODREG_0","PRODREG_1","PRODREG_2","PRODREG_3","UNIT_VEG_GROS_0","UNIT_VEG_GROS_1","UNIT_VEG_GROS_2","UNIT_VEG_GROS_3","UNIT_VEG_GROS_4","UNIT_VEG_GROS_5","UNIT_VEG_GROS_6","UNIT_VEG_GROS_7","UNIT_VEG_GROS_8","UNIT_VEG_GROS_9","UNIT_VEG_GROS_10","UNIT_VEG_GROS_11","UNIT_VEG_GROS_12","UNIT_VEG_GROS_13","UNIT_VEG_GROS_14","UNIT_VEG_GROS_15","UNIT_VEG_GROS_16","MODE_REGEN_0","MODE_REGEN_1","MODE_REGEN_2","MODE_REGEN_3","INTENSITE_EXPLOIT_0","INTENSITE_EXPLOIT_1","INTENSITE_EXPLOIT_2","TRACES_FEU_0","NIV_DEV_0","NIV_DEV_1","NIV_DEV_2","NIV_DEV_3","NIV_DEV_4","NIV_DEV_5","RELIEF_0","RELIEF_1","RELIEF_2","RELIEF_3","RELIEF_4","DEG_FERMETURE_0","DEG_FERMETURE_1","DEG_FERMETURE_2","DEG_FERMETURE_3","DEG_FERMETURE_4","DEG_FERMETURE_5","DEG_FERMETURE_6","DEG_FERMETURE_7","DEG_FERMETURE_8","DEG_FERMETURE_9","DEG_FERMETURE_10","STR_PPL_0","STR_PPL_1","STR_PPL_2","STR_PPL_3","TYPE_FORET305_0","TYPE_FORET305_1","TYPE_FORET305_2","TYPE_FORET305_3","TYPE_FORET305_4","TYPE_FORET305_5","TYPE_FORET305_6","TYPE_FORET305_7","TYPE_FORET305_8","TYPE_FORET305_9","TYPE_FORET305_10","TYPE_FORET305_11","TYPE_FORET305_12","TYP_RAJ_PPL_0","TYP_RAJ_PPL_1","TYP_RAJ_PPL_2","TAUX_COUV_RAJ_ASS_0","TAUX_COUV_RAJ_ASS_1","TAUX_COUV_RAJ_ASS_2","TAUX_COUV_RAJ_ASS_3","TAUX_COUV_RAJ_ASS_4","TAUX_COUV_RAJ_ASS_5","TAUX_COUV_RAJ_ASS_6","ESPECE_DOM_0","ESPECE_DOM_1","ESPECE_DOM_2","ESPECE_DOM_3","ESPECE_DOM_4","ESPECE_DOM_5","ESPECE_DOM_6","ESPECE_DOM_7","ESPECE_DOM_8","ESPECE_DOM_9","ESPECE_DOM_10","ESPECE_DOM_11","TYPE_FORET_0","TYPE_FORET_1","TYPE_FORET_2","TYPE_FORET_3","TYPE_FORET_4","DEGRAD_PPL_0","DEGRAD_PPL_1","DEGRAD_PPL_2","DEGRAD_PPL_3","DEGRAD_PPL_4","DEGRAD_PPL_5","TAUX_COUV_RAJ_0","TAUX_COUV_RAJ_1","TAUX_COUV_RAJ_2","TAUX_COUV_RAJ_3","TAUX_COUV_RAJ_4","TAUX_COUV_RAJ_5"],"xaxis":"x","y":[2.3028048478818834,-0.17176945237360167,0.1572018930899494,0.23210745319981813,0.22221558229355012,1.2698385392906282,3.6022475428611758,0.2867242536611697,0.6602435893555715,0.010047384069705897,-0.4202141473700411,-0.1000033495407681,0.1386433056644021,0.09111234654533489,-0.0,0.3950106824936764,0.14141294651909708,-0.4036541671826609,0.20171636785006333,-0.008379218437825514,0.014692339395830712,0.45956050147340644,0.22518982597743473,0.0678178456110156,17.084704897077476,0.0,-1.5018408755997545,0.5214829839930042,1.2501209751085016,0.9890942731566487,-0.07158713954048244,0.8749283388590602,0.10231050252985835,-0.08576541740537405,0.024572241845625325,2.9616032954516003,0.440792738479974,-0.013382347808445895,-0.742305003899090 ...
